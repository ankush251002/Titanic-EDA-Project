# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('Titanic-Dataset.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 410          411         0       3
# 713          714         0       3
# 856          857         1       1
# 860          861         0       3
# 160          161         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 410                          Sdycoff, Mr. Todor    male   NaN      0      0
# 713                  Larsson, Mr. August Viktor    male  29.0      0      0
# 856  Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1      1
# 860                     Hansen, Mr. Claus Peter    male  41.0      2      0
# 160                    Cribb, Mr. John Hatfield    male  44.0      0      1
#
#      Ticket      Fare Cabin Embarked
# 410  349222    7.8958   NaN        S
# 713    7545    9.4833   NaN        S
# 856   36928  164.8667   NaN        S
# 860  350026   14.1083   NaN        S
# 160  371362   16.1000   NaN        S

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print(data.shape)
print('rows,columns')
# Out:
# (891, 12)
# rows,columns

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
#  # Statistical overview of dataset

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # To know how many null values in dataset

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
missing_val =[val for val  in data.columns if data[val].isnull().sum() > 0 ]
print(len(missing_val),' columns has null values')
print('The columns are',missing_val)
# Out:
# 3  columns has null values
# The columns are ['Age', 'Cabin', 'Embarked']

# %%
plt.figure(figsize=(5,5))
sb.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # To split Numeric data as numdata
# # Catogical data as catdata

# %%
catcol = [cat for cat in data.columns if data[cat].dtypes=='object']
numcol = [num for num in data.columns if data[num].dtype!='object'] 
print(f'Total {len(catcol)} categorical data columns are {catcol}')
print(f'Total {len(numcol)} numerical data columns are {numcol}')
# Out:
# Total 5 categorical data columns are ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']
# Total 7 numerical data columns are ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
catdata = data[catcol]
catdata
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
numdata = data[numcol]
numdata
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
numdata.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# dtype: int64

# %%
numdata['Age'] = numdata['Age'].fillna(numdata['Age'].median())

# %%
numdata.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# dtype: int64

# %%
numdata
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3  28.0      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
catdata
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
catdata.isna().sum()
# Out:
# Name          0
# Sex           0
# Ticket        0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
catdata['Embarked'] = catdata['Embarked'].fillna(catdata['Embarked'].mode().iloc[0])

# %%
catdata.isna().sum()
# Out:
# Name          0
# Sex           0
# Ticket        0
# Cabin       687
# Embarked      0
# dtype: int64

# %%
catdata['Cabin']=catdata['Cabin'].fillna('Unknown')

# %%
catdata
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket    Cabin Embarked
# 0           A/5 21171  Unknown        S
# 1            PC 17599      C85        C
# 2    STON/O2. 3101282  Unknown        S
# 3              113803     C123        S
# ...

# %% [markdown]
# # Numeric data visualization

# %%
sb.histplot(numdata['Age'], kde=True)
plt.title('Age distributation of Passenger')
plt.show()

# %%
sb.histplot(numdata['Parch'], kde=True)
plt.title('Parent and children distributation of Passenger')
plt.show()

# %%
sb.histplot(numdata['SibSp'], kde=True)
plt.title('Siblings/Spouse distributation of Passenger')
plt.show()

# %%
sb.countplot(x='Pclass',data=numdata)
plt.title('Class distribuation')
plt.show()

# %% [markdown]
# # To check or detect ouliers

# %%
sb.boxplot(x=numdata['Fare'])
plt.title('Fare Distribuation')
plt.show()

# %% [markdown]
# Categorical data visulzation

# %%
sb.countplot(x=catdata['Sex'])
plt.title('Gender Distribuation')
plt.show()

# %%
sb.countplot(x=catdata['Embarked'])
plt.title('Embarkation distribuation')
plt.show()

# %% [markdown]
# # Bivariate analysis (relationship between two variables)

# %%
# survival Genderwise 
sb.countplot(x='Survived', hue='Sex', data=data)
plt.title("Survival by Gender")
plt.show()

# %%
# classwise survival 
sb.countplot(x='Survived', hue='Pclass', data=data)
plt.title("Survival by Passenger Class")
plt.show()

# %%
#embarked survival
sb.countplot(x='Survived', hue='Embarked', data=data)
plt.title("Survival by Embarked")
plt.show()

# %%
# Age wise survival
sb.boxplot(x='Survived', y='Age', data=data)
plt.title("Age vs Survival")
plt.show()

# %%
# fare wise survial 
sb.boxplot(x='Survived', y='Fare', data=data)
plt.title("Fare vs Survival")
plt.show()

# %%
sb.scatterplot(x='Age', y='Fare', hue='Survived', data=data)
plt.title("Age vs Fare (Colored by Survival)")
plt.show()

# %%
numdata.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.034212 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.064910 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.339898  0.083081  0.018443
# Age             0.034212 -0.064910 -0.339898  1.000000 -0.233296 -0.172482
# SibSp          -0.057527 -0.035322  0.083081 -0.233296  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.172482  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096688  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096688
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
plt.figure(figsize=(8,6))
sb.heatmap(numdata.corr(), annot=True, cmap='Blues')
plt.title("Correlation Heatmap - Numerical Features")
plt.show()

# %% [markdown]
# # Conclusion :
# # The  conclusion of my analysis of titanic dataset revels that survival was not random.
# # instead it was heavily influenced by passenger's gender , socio-economic status and age.
# # And also thoes who paid higher fare had higher probility of survial.
